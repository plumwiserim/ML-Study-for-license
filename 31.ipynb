# %% [markdown]
# ### 대응표본 t검정(paired)

# %%
# 문제. 특정 질병 집단의 투약 전후의 혈류량 변화를 나타낸 데이터이다. 
# 투약 전후의 변화가 있는지 검정하라 

import pandas as pd 

df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/scipy/rel2.csv')

import matplotlib.pyplot as plt 

fig, ax = plt.subplots(1, 2)
ax[0].boxplot(df['before'])
ax[0].set_xticklabels['before']
ax[0].set_ylim(100, 350)
ax[0].set_ylabel('value')
ax[1].boxplot(df['after'])
ax[1].set_xticklabels(['after'])
ax[1].set_ylim(100, 350)
ax[1].get_yaxis().set_visible(False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\LEE\Desktop\ML-Study-for-license\31.ipynb Cell 2 in 1
#      <a href='vscode-notebook-cell:/c%3A/Users/LEE/Desktop/ML-Study-for-license/31.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a> fig, ax = plt.subplots(1, 2)
#      <a href='vscode-notebook-cell:/c%3A/Users/LEE/Desktop/ML-Study-for-license/31.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a> ax[0].boxplot(df['before'])
# ---> <a href='vscode-notebook-cell:/c%3A/Users/LEE/Desktop/ML-Study-for-license/31.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a> ax[0].set_xticklabels['before']
#      <a href='vscode-notebook-cell:/c%3A/Users/LEE/Desktop/ML-Study-for-license/31.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a> ax[0].set_ylim(100, 350)
#      <a href='vscode-notebook-cell:/c%3A/Users/LEE/Desktop/ML-Study-for-license/31.ipynb#W2sZmlsZQ%3D%3D?line=13'>14</a> ax[0].set_ylabel('value')
#
# TypeError: 'method' object is not subscriptable

# %%
from scipy.stats import shapiro

before = df['before']
after = df['after']

print(shapiro(before))
print(shapiro(after))
print()

from scipy.stats import levene
