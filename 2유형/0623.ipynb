# %% [markdown]
# 기본단계

# %%
# 출력을 원하실 경우 print() 함수 활용
# 예시) print(df.head())

# getcwd(), chdir() 등 작업 폴더 설정 불필요
# 파일 경로 상 내부 드라이브 경로(C: 등) 접근 불가

# 데이터 파일 읽기 예제
import pandas as pd
X_test = pd.read_csv("data/X_test.csv")
X_train = pd.read_csv("data/X_train.csv")
y_train = pd.read_csv("data/y_train.csv")

# 사용자 코딩
# 1. 데이터 확인 
# print(X_train.info())	# 결측치: 환불금액, 범주형: 주구매상품, 주구매지점
# print(y_train.info()) # 
# print(X_test.info())  # 결측치: 환불금액, 범주형: 주구매상품, 주구매지점 

# print(X_train.head())
# print(y_train.head())
# print(X_test.head())

# print(X_train.shape)

# 2. 데이터 전처리 
# 불필요한 컬럼 없애주기 
X_train = X_train.drop(['cust_id'], axis=1)
y_train = y_train.drop(['cust_id'], axis=1)

cust_id = X_test['cust_id']
X_test = X_test.drop(['cust_id'], axis=1)

# print(X_train.head())
# print(X_train.shape)

# 결측치 제거 
X_train = X_train.drop(['환불금액'], axis=1)
X_test = X_test.drop(['환불금액'], axis=1)

print(X_train.shape)

# 범주형 변수 처리 
# X_train = pd.get_dummies(X_train)

from sklearn.preprocessing import LabelEncoder 

encoder = LabelEncoder()
X_train['주구매상품'] = encoder.fit_transform(X_train['주구매상품'])
X_test['주구매상품'] = encoder.fit_transform(X_test['주구매상품'])

X_train['주구매지점'] = encoder.fit_transform(X_train['주구매지점'])
X_test['주구매지점'] = encoder.fit_transform(X_test['주구매지점'])

print(X_train.head())

# 예측 모델 
from sklearn.ensemble import RandomForestClassifier
import numpy as np 

rf_model = RandomForestClassifier()
rf_model.fit(X_train, np.ravel(y_train))
y_pred = rf_model.predict_proba(X_test)

# 모델 실행 
print(y_pred[:, 1])

# 답안 제출 
answer = {'cust_id': cust_id, 
				'gender': y_pred[:, 1]}
answer = pd.DataFrame(answer)
print(answer)

answer.to_csv('suhumbeonho.csv', index=False)

# 답안 제출 참고
# 아래 코드 예측변수와 수험번호를 개인별로 변경하여 활용
# pd.DataFrame({'cust_id': X_test.cust_id, 'gender': pred}).to_csv('003000000.csv', index=False)

# %% [markdown]
# +) 성능 평가

# %%
# 출력을 원하실 경우 print() 함수 활용
# 예시) print(df.head())

# getcwd(), chdir() 등 작업 폴더 설정 불필요
# 파일 경로 상 내부 드라이브 경로(C: 등) 접근 불가

# 데이터 파일 읽기 예제
import pandas as pd
X_test = pd.read_csv("data/X_test.csv")
X_train = pd.read_csv("data/X_train.csv")
y_train = pd.read_csv("data/y_train.csv")

# 사용자 코딩
# 1. 데이터 확인 
# print(X_train.info())	# 결측치: 환불금액, 범주형: 주구매상품, 주구매지점
# print(y_train.info()) # 
# print(X_test.info())  # 결측치: 환불금액, 범주형: 주구매상품, 주구매지점 

# print(X_train.head())
# print(y_train.head())
# print(X_test.head())

# print(X_train.shape)

# 2. 데이터 전처리 
# 불필요한 컬럼 없애주기 
X_train = X_train.drop(['cust_id'], axis=1)
y_train = y_train.drop(['cust_id'], axis=1)

cust_id = X_test['cust_id']
X_test = X_test.drop(['cust_id'], axis=1)

# print(X_train.head())
# print(X_train.shape)

# 결측치 제거 
X_train = X_train.drop(['환불금액'], axis=1)
X_test = X_test.drop(['환불금액'], axis=1)

print(X_train.shape)

# 범주형 변수 처리 
# X_train = pd.get_dummies(X_train)

from sklearn.preprocessing import LabelEncoder 

encoder = LabelEncoder()
X_train['주구매상품'] = encoder.fit_transform(X_train['주구매상품'])
X_test['주구매상품'] = encoder.transform(X_test['주구매상품'])

X_train['주구매지점'] = encoder.fit_transform(X_train['주구매지점'])
X_test['주구매지점'] = encoder.transform(X_test['주구매지점'])

# print(X_train.head())

# train / test split 
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2)

print(X_train.shape)
print(X_valid.shape)
print(y_train.shape)
print(y_valid.shape)

# 예측 모델 
import numpy as np 
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier()
rf_model.fit(X_train, np.ravel(y_train))
y_valid_pred = rf_model.predict_proba(X_valid)[:, 1]

# 성능 평가 
from sklearn.metrics import roc_auc_score

print(roc_auc_score(y_valid, y_valid_pred))

# 모델 실행 
y_pred = rf_model.predict_proba(X_test)

# 답안 제출 
answer = {'cust_id': cust_id, 
				'gender': y_pred[:, 1]}
answer = pd.DataFrame(answer)
print(answer)

answer.to_csv('suhumbeonho.csv', index=False)

# 답안 제출 참고
# 아래 코드 예측변수와 수험번호를 개인별로 변경하여 활용
# pd.DataFrame({'cust_id': X_test.cust_id, 'gender': pred}).to_csv('003000000.csv', index=False)

# %% [markdown]
# 심화단계

# %%
# !git clone https://github.com/7ieon/bigData
# Out:
# Cloning into 'bigData'...

# %%
import pandas as pd 

X_train = pd.read_csv('.\\bigData\\titanic_x_train.csv', encoding='cp949')
X_test = pd.read_csv('.\\bigData\\titanic_x_test.csv', encoding='cp949')
y_train = pd.read_csv('.\\bigData\\titanic_y_train.csv', encoding='cp949')

y_train.columns.values[0] = 'PassengerId'

# print(X_train.info())       # 결측치: 나이, 객실번호, 선착장    범주형: 성별, 티켓번호, 객실번호, 선착장 
# print(X_test.info())        # 결측치: 나이, 운임요금, 객실번호  범주형: 성별, 티켓번호, 객실번호, 선착장 
# print(y_train.info())       

# print(X_train.shape)
# print(X_test.shape)
# print(y_train.shape)

# 전처리 
# unique 컬럼 제거  # X, y: PassengerId, X: 승객이름
X_train = X_train.drop(['PassengerId', '승객이름', '티켓번호'], axis=1) 
y_train = y_train.drop(['PassengerId'], axis=1) 

passenger_id = X_test['PassengerId']
X_test = X_test.drop(['PassengerId', '승객이름', '티켓번호'], axis=1) 

# print(X_train.shape)
# print(X_test.shape)
# print(y_train.shape)

# 결측치 처리   # 객실번호 
X_train = X_train.drop(['객실번호'], axis=1) 
X_test = X_test.drop(['객실번호'], axis=1) 


# 범주형 변수 처리 

# train / test split 

# 예측 모델: 분류 

# 성능 평가: accuracy 

# 답안 제출
